# %% [markdown]
# ## Imports and data initialization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_style("darkgrid")
# %matplotlib inline

# %%
data = pd.Series([-20, -60, -10, 30, 60, 70, -10, -30, -120, -100, -80, 20, 40, -60, -10, 20, 30, -80, 60, 70])

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Density function

# %%
sns.kdeplot(data, cumulative=True);

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data);
